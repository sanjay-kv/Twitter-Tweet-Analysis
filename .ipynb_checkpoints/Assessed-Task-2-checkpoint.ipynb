# %%
import tweepy
import pandas as pd
import numpy as np
import json
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Establishing the connection
# Created and Application in Twitter Developer account as Assessed-task-2 & copied the keyboard.

# %%
# Application creds made in developer account ...

consumer_key = 'jIXCU53opEikJKYRWK633SRTd'
consumer_key_secret = 'NTx4NDFUfJMuAZwg7DX4kRW7ZMpWUYUe8ZXi7fH8C5jWHhn4UZ'
access_token = '1371716702-hRzyepHlBcKVTvhI0W6Npdd7p78GjHEZb4w9v0y'
access_token_secret = 'JdvZubB0HLeqRY7qJLZ7oFZH2q9R2BPInDZ30TVEWnM7q'

auth = tweepy.OAuthHandler(consumer_key, consumer_key_secret)
# Authorisation of API key and API key secret.
auth.set_access_token(access_token, access_token_secret)
# Set access to user's access token and access token secret.
api = tweepy.API(auth)
# The API class provides access to the Twitter RESTful API method.

# %% [markdown]
# ### Testing the connection

# %%
# Testing the authentication.
try:
    user = api.verify_credentials()
    print('Authentication OK.')
except:
    print('Error during authentication.')
# Out:
# Authentication OK.

# %% [markdown]
# ## Task 1
# Collect 400 tweets from two different Twitter users **(Australian politicians)**, 200 from each.  You should try to find two politicians where you would expect there to be some noticeable differences in their tweets.
#
# **Selected politician for the Assessments:**<br>
# Malcolm Turnbull with Screen name: @TurnbullMalcolm    *-Former PM of Australia. (2014-2018)*<br>
# Kevin Rudd with Screen name: @MrKRudd      -* Former PM of Australia.*

# %% [markdown]
# #### Collecting first 200 tweets of Malcolm Turnbull with Screen name: @TurnbullMalcolm

# %%
max_tweets = 200
screen_name = '@TurnbullMalcolm'
tweets_Malcolm = api.user_timeline(screen_name = screen_name, tweet_mode = 'extended', count = max_tweets)

# %%
Malcolm = []
for tweet in tweets_Malcolm:
    Malcolm.append(tweet._json)

with open('Data_scrapped/TurnbullMalcolm.json', mode = 'w') as file:
    file.write(json.dumps(Malcolm , indent = 4))

# %% [markdown]
# #### Collecting first 200 tweets of Malcolm Turnbull with Screen name: @TurnbullMalcolm

# %%
max_tweets = 200
screen_name = '@MrKRudd'
tweets_Rudd = api.user_timeline(screen_name = screen_name,tweet_mode = 'extended', count = max_tweets)

# %%
Rudd = []
for tweet in tweets_Rudd:
    Rudd.append(tweet._json)
    
with open('Data_scrapped/MrKRudd.json', mode = 'w') as file:
    file.write(json.dumps(Rudd , indent = 4))

# %% [markdown]
# # Task 2
# Use pandas to plot the posting times of the tweets for the two users in one bar chart; the aim of the plot is to distinguish the two users.

# %% [markdown]
# #### Creating listing for Malcolm

# %%
#listing the Malcolm Tweets and timings
Malcolm = []
with open('Data_scrapped/TurnbullMalcolm.json', encoding = 'utf-8', mode = 'r') as file:
        Malcolm_list = json.load(file)
        for dict in Malcolm_list:
             Malcolm.append({'user_id':str(dict['user']['name']),
                           'post_time':dict['created_at'],
                          'tweet':str(dict['full_text']),  
             })

# %%
Malcolm_df = pd.DataFrame(Malcolm , columns = ['user_id','post_time','tweet', ])
Malcolm_df.head(10)
# Out:
#                user_id                       post_time  \
# 0  Malcolm Turnbull 💉💉  Fri Oct 15 11:54:20 +0000 2021
# 1  Malcolm Turnbull 💉💉  Fri Oct 15 10:36:49 +0000 2021
# 2  Malcolm Turnbull 💉💉  Fri Oct 15 08:32:01 +0000 2021
# 3  Malcolm Turnbull 💉💉  Fri Oct 15 05:23:29 +0000 2021
# 4  Malcolm Turnbull 💉💉  Thu Oct 14 05:02:42 +0000 2021
# 5  Malcolm Turnbull 💉💉  Thu Oct 14 02:47:14 +0000 2021
# 6  Malcolm Turnbull 💉💉  Thu Oct 14 00:05:39 +0000 2021
# 7  Malcolm Turnbull 💉💉  Wed Oct 13 23:54:51 +0000 2021
# 8  Malcolm Turnbull 💉💉  Wed Oct 13 21:23:44 +0000 2021
# 9  Malcolm Turnbull 💉💉  Wed Oct 13 21:06:58 +0000 2021
#
#                                                tweet
# 0  RT @mjrowland68: This is quite the column by @...
# 1  RT @energynetworks: Join former Australian Pri...
# 2  RT @WarOnTheRocks: "The hyperbole around the n...
# 3  Australia’s ageing submarine fleet could still...
# 4  Andrew Forrest urges Scott Morrison to commit ...
# 5  RT @FortescueFuture: This morning our founder ...
# 6  Very well deserved accolade for Tony Smith by ...
# 7  RT @SmartEnergyCncl: Renewable #hydrogen is ke...
# 8  RT @PaulBongiorno: Listening to Twiggy Forrest...
# 9  @DAlperovitch @alperovitch @SAISHopkins @RidT ...

# %%
#checking only 200 rows are fetched here.
Malcolm_df.shape
# Out:
# (200, 3)

# %%
Malcolm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    200 non-null    object
#  1   post_time  200 non-null    object
#  2   tweet      200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
#Need to change the datatype further for plotting post time,Hour
Malcolm_df['post_time'] = pd.to_datetime(Malcolm_df['post_time'])
Malcolm_df['hour'] = Malcolm_df['post_time'].dt.hour

# %%
Malcolm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    200 non-null    object
#  1   post_time  200 non-null    datetime64[ns, UTC]
#  2   tweet      200 non-null    object
#  3   hour       200 non-null    int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# #### Creating lisitng for MrKRudd

# %%
#listing the Malcolm Tweets and timings
Rudd = []
with open('Data_scrapped/MrKRudd.json', encoding = 'utf-8', mode = 'r') as file:
        Rudd_list = json.load(file)
        for dict in Rudd_list:
             Rudd.append({'user_id':str(dict['user']['name']),
                           'post_time':dict['created_at'],
                          'tweet':str(dict['full_text']),  
             })

# %%
Rudd_df = pd.DataFrame(Rudd , columns = ['user_id','post_time','tweet', ])
Rudd_df.head(10)
# Out:
#       user_id                       post_time  \
# 0  Kevin Rudd  Fri Oct 15 02:02:14 +0000 2021
# 1  Kevin Rudd  Fri Oct 15 01:09:51 +0000 2021
# 2  Kevin Rudd  Thu Oct 14 08:53:46 +0000 2021
# 3  Kevin Rudd  Thu Oct 14 05:29:50 +0000 2021
# 4  Kevin Rudd  Wed Oct 13 02:08:32 +0000 2021
# 5  Kevin Rudd  Tue Oct 12 23:08:15 +0000 2021
# 6  Kevin Rudd  Tue Oct 12 02:59:41 +0000 2021
# 7  Kevin Rudd  Tue Oct 12 01:23:00 +0000 2021
# 8  Kevin Rudd  Mon Oct 11 22:51:00 +0000 2021
# 9  Kevin Rudd  Mon Oct 11 20:03:00 +0000 2021
#
#                                                tweet
# 0  A classic Morrison hatchet job. This professio...
# 1  Memo to Morrison: We are not amused. https://t...
# 2  Young Australians are miles ahead of Morrison ...
# 3  This is just dangerous with NSW coming out of ...
# 4  Prepare for more of this sort of fearless &amp...
# 5  Cynically pretend to one audience you now supp...
# 6  You know Morrison has really gone beyond the p...
# 7  Murdoch is today predicting an investment bona...
# 8  Murdoch now says that decarbonising the econom...
# 9  Murdoch spent years working hand-in-glove with...

# %%
#checking only 200 rows are fetched here.
Rudd_df.shape
# Out:
# (200, 3)

# %%
Rudd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    200 non-null    object
#  1   post_time  200 non-null    object
#  2   tweet      200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
#Need to change the datatype further for plotting post time,Hour
Rudd_df['post_time'] = pd.to_datetime(Rudd_df['post_time'])
Rudd_df['hour'] = Rudd_df['post_time'].dt.hour

# %%
Rudd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    200 non-null    object
#  1   post_time  200 non-null    datetime64[ns, UTC]
#  2   tweet      200 non-null    object
#  3   hour       200 non-null    int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Listing Both Twitter Account to one table

# %%
df = pd.concat([Malcolm_df,Rudd_df], axis=0).reset_index()
df
# Out:
#      index              user_id                 post_time  \
# 0        0  Malcolm Turnbull 💉💉 2021-10-15 11:54:20+00:00
# 1        1  Malcolm Turnbull 💉💉 2021-10-15 10:36:49+00:00
# 2        2  Malcolm Turnbull 💉💉 2021-10-15 08:32:01+00:00
# 3        3  Malcolm Turnbull 💉💉 2021-10-15 05:23:29+00:00
# 4        4  Malcolm Turnbull 💉💉 2021-10-14 05:02:42+00:00
# ..     ...                  ...                       ...
# 395    195           Kevin Rudd 2021-08-16 23:51:00+00:00
# 396    196           Kevin Rudd 2021-08-16 15:05:08+00:00
# 397    197           Kevin Rudd 2021-08-16 06:54:26+00:00
# 398    198           Kevin Rudd 2021-08-16 05:01:02+00:00
# 399    199           Kevin Rudd 2021-08-15 11:58:19+00:00
#
#                                                  tweet  hour
# 0    RT @mjrowland68: This is quite the column by @...    11
# 1    RT @energynetworks: Join former Australian Pri...    10
# 2    RT @WarOnTheRocks: "The hyperbole around the n...     8
# 3    Australia’s ageing submarine fleet could still...     5
# 4    Andrew Forrest urges Scott Morrison to commit ...     5
# ..                                                 ...   ...
# 395  John Howard and I have been calling for this e...    23
# 396  Incompetent on vaccines. Incompetent on quaran...    15
# 397  During a national emergency, Murdoch's Sky New...     6
# 398  First, Murdoch undermines lockdowns, pressurin...     5
# 399  This is unbelievable, potentially lethal negli...    11
#
# [400 rows x 5 columns]

# %% [markdown]
# ### Plotting the Bar Graph

# %%
ax1 = Malcolm_df['hour'].value_counts().sort_index().plot.bar(figsize = (15, 8), color = 'green')
ax2 = Rudd_df['hour'].value_counts().sort_index().plot.bar(figsize = (15, 8))
ax1.set_title('Tweets timing of Malcolm-green and Rudd-Blue')
ax1.set_ylabel('No of Tweets')
ax1.set_xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# Should add the bar representing each color above

# %% [markdown]
# ## Task 3

# %% [markdown]
# Use pandas to construct one bar chart of the proportions of tweets for each of the two users that contain pictures or links.

# %%
#using regular expression to filter it out
df['text_without_links'] = df['tweet'].str.replace('http\S+|www.\S+', '', case = False)
df
# Out:
#      index              user_id                 post_time  \
# 0        0  Malcolm Turnbull 💉💉 2021-10-15 11:54:20+00:00
# 1        1  Malcolm Turnbull 💉💉 2021-10-15 10:36:49+00:00
# 2        2  Malcolm Turnbull 💉💉 2021-10-15 08:32:01+00:00
# 3        3  Malcolm Turnbull 💉💉 2021-10-15 05:23:29+00:00
# 4        4  Malcolm Turnbull 💉💉 2021-10-14 05:02:42+00:00
# ..     ...                  ...                       ...
# 395    195           Kevin Rudd 2021-08-16 23:51:00+00:00
# 396    196           Kevin Rudd 2021-08-16 15:05:08+00:00
# 397    197           Kevin Rudd 2021-08-16 06:54:26+00:00
# 398    198           Kevin Rudd 2021-08-16 05:01:02+00:00
# 399    199           Kevin Rudd 2021-08-15 11:58:19+00:00
#
#                                                  tweet  hour  \
# 0    RT @mjrowland68: This is quite the column by @...    11
# 1    RT @energynetworks: Join former Australian Pri...    10
# 2    RT @WarOnTheRocks: "The hyperbole around the n...     8
# 3    Australia’s ageing submarine fleet could still...     5
# 4    Andrew Forrest urges Scott Morrison to commit ...     5
# ..                                                 ...   ...
# 395  John Howard and I have been calling for this e...    23
# 396  Incompetent on vaccines. Incompetent on quaran...    15
# 397  During a national emergency, Murdoch's Sky New...     6
# 398  First, Murdoch undermines lockdowns, pressurin...     5
# 399  This is unbelievable, potentially lethal negli...    11
#
#                                     text_without_links
# 0    RT @mjrowland68: This is quite the column by @...
# 1    RT @energynetworks: Join former Australian Pri...
# 2    RT @WarOnTheRocks: "The hyperbole around the n...
# 3    Australia’s ageing submarine fleet could still...
# 4    Andrew Forrest urges Scott Morrison to commit ...
# ..                                                 ...
# 395  John Howard and I have been calling for this e...
# 396  Incompetent on vaccines. Incompetent on quaran...
# 397  During a national emergency, Murdoch's Sky New...
# 398  First, Murdoch undermines lockdowns, pressurin...
# 399  This is unbelievable, potentially lethal negli...
#
# [400 rows x 6 columns]

# %%
df['tweet_links'] = df['tweet'].apply(lambda x: re.findall(r"http\S+|www.\S+", x))
df
# Out:
#      index              user_id                 post_time  \
# 0        0  Malcolm Turnbull 💉💉 2021-10-15 11:54:20+00:00
# 1        1  Malcolm Turnbull 💉💉 2021-10-15 10:36:49+00:00
# 2        2  Malcolm Turnbull 💉💉 2021-10-15 08:32:01+00:00
# 3        3  Malcolm Turnbull 💉💉 2021-10-15 05:23:29+00:00
# 4        4  Malcolm Turnbull 💉💉 2021-10-14 05:02:42+00:00
# ..     ...                  ...                       ...
# 395    195           Kevin Rudd 2021-08-16 23:51:00+00:00
# 396    196           Kevin Rudd 2021-08-16 15:05:08+00:00
# 397    197           Kevin Rudd 2021-08-16 06:54:26+00:00
# 398    198           Kevin Rudd 2021-08-16 05:01:02+00:00
# 399    199           Kevin Rudd 2021-08-15 11:58:19+00:00
#
#                                                  tweet  hour  \
# 0    RT @mjrowland68: This is quite the column by @...    11
# 1    RT @energynetworks: Join former Australian Pri...    10
# 2    RT @WarOnTheRocks: "The hyperbole around the n...     8
# 3    Australia’s ageing submarine fleet could still...     5
# 4    Andrew Forrest urges Scott Morrison to commit ...     5
# ..                                                 ...   ...
# 395  John Howard and I have been calling for this e...    23
# 396  Incompetent on vaccines. Incompetent on quaran...    15
# 397  During a national emergency, Murdoch's Sky New...     6
# 398  First, Murdoch undermines lockdowns, pressurin...     5
# 399  This is unbelievable, potentially lethal negli...    11
#
#                                     text_without_links  \
# 0    RT @mjrowland68: This is quite the column by @...
# 1    RT @energynetworks: Join former Australian Pri...
# 2    RT @WarOnTheRocks: "The hyperbole around the n...
# 3    Australia’s ageing submarine fleet could still...
# 4    Andrew Forrest urges Scott Morrison to commit ...
# ..                                                 ...
# 395  John Howard and I have been calling for this e...
# 396  Incompetent on vaccines. Incompetent on quaran...
# 397  During a national emergency, Murdoch's Sky New...
# 398  First, Murdoch undermines lockdowns, pressurin...
# 399  This is unbelievable, potentially lethal negli...
#
#                    tweet_links
# 0                           []
# 1                           []
# 2    [https://t.co/HUQOvyL5y9]
# 3    [https://t.co/DZPNMWIGwL]
# 4    [https://t.co/ehIskk3GWm]
# ..                         ...
# 395  [https://t.co/r80zPrXBoK]
# 396  [https://t.co/mKs0EtJTzk]
# 397  [https://t.co/5BNKqLqqsc]
# 398  [https://t.co/tbWM2jU7Dw]
# 399  [https://t.co/2OrI4HcfTU]
#
# [400 rows x 7 columns]

# %%
linked_tweet = df['tweet'].apply(lambda x: re.findall(r"http\S+|www.\S+", x))
linked_tweet
# Out:
# 0                             []
# 1                             []
# 2      [https://t.co/HUQOvyL5y9]
# 3      [https://t.co/DZPNMWIGwL]
# 4      [https://t.co/ehIskk3GWm]
#                  ...
# 395    [https://t.co/r80zPrXBoK]
# 396    [https://t.co/mKs0EtJTzk]
# 397    [https://t.co/5BNKqLqqsc]
# 398    [https://t.co/tbWM2jU7Dw]
# 399    [https://t.co/2OrI4HcfTU]
# Name: tweet, Length: 400, dtype: object

# %%
df['links_boolean'] = df['tweet'].apply(lambda x: re.findall(r"http\S+|www.\S+", x)).apply((lambda x: len(x) != 0))
df = df.reset_index()                                 
df
# Out:
#      level_0  index              user_id                 post_time  \
# 0          0      0  Malcolm Turnbull 💉💉 2021-10-15 11:54:20+00:00
# 1          1      1  Malcolm Turnbull 💉💉 2021-10-15 10:36:49+00:00
# 2          2      2  Malcolm Turnbull 💉💉 2021-10-15 08:32:01+00:00
# 3          3      3  Malcolm Turnbull 💉💉 2021-10-15 05:23:29+00:00
# 4          4      4  Malcolm Turnbull 💉💉 2021-10-14 05:02:42+00:00
# ..       ...    ...                  ...                       ...
# 395      395    195           Kevin Rudd 2021-08-16 23:51:00+00:00
# 396      396    196           Kevin Rudd 2021-08-16 15:05:08+00:00
# 397      397    197           Kevin Rudd 2021-08-16 06:54:26+00:00
# 398      398    198           Kevin Rudd 2021-08-16 05:01:02+00:00
# 399      399    199           Kevin Rudd 2021-08-15 11:58:19+00:00
#
#                                                  tweet  hour  \
# 0    RT @mjrowland68: This is quite the column by @...    11
# 1    RT @energynetworks: Join former Australian Pri...    10
# 2    RT @WarOnTheRocks: "The hyperbole around the n...     8
# 3    Australia’s ageing submarine fleet could still...     5
# 4    Andrew Forrest urges Scott Morrison to commit ...     5
# ..                                                 ...   ...
# 395  John Howard and I have been calling for this e...    23
# 396  Incompetent on vaccines. Incompetent on quaran...    15
# 397  During a national emergency, Murdoch's Sky New...     6
# 398  First, Murdoch undermines lockdowns, pressurin...     5
# 399  This is unbelievable, potentially lethal negli...    11
#
#                                     text_without_links  \
# 0    RT @mjrowland68: This is quite the column by @...
# 1    RT @energynetworks: Join former Australian Pri...
# 2    RT @WarOnTheRocks: "The hyperbole around the n...
# 3    Australia’s ageing submarine fleet could still...
# 4    Andrew Forrest urges Scott Morrison to commit ...
# ..                                                 ...
# 395  John Howard and I have been calling for this e...
# 396  Incompetent on vaccines. Incompetent on quaran...
# 397  During a national emergency, Murdoch's Sky New...
# 398  First, Murdoch undermines lockdowns, pressurin...
# 399  This is unbelievable, potentially lethal negli...
#
#                    tweet_links  links_boolean
# 0                           []          False
# 1                           []          False
# 2    [https://t.co/HUQOvyL5y9]           True
# 3    [https://t.co/DZPNMWIGwL]           True
# 4    [https://t.co/ehIskk3GWm]           True
# ..                         ...            ...
# 395  [https://t.co/r80zPrXBoK]           True
# 396  [https://t.co/mKs0EtJTzk]           True
# 397  [https://t.co/5BNKqLqqsc]           True
# 398  [https://t.co/tbWM2jU7Dw]           True
# 399  [https://t.co/2OrI4HcfTU]           True
#
# [400 rows x 9 columns]

# %%
#Create new df to calculate proportion of tweet including pictures or links
Picture_df = df.groupby(['user_id','links_boolean']).size().reset_index(name ='count')
Picture_df['total'] = Picture_df.groupby(['user_id'])['count'].transform('sum')
Picture_df = Picture_df.sort_values(by=['total'], ascending=False)
Picture_df.head(10)
# Out:
#                user_id  links_boolean  count  total
# 0           Kevin Rudd          False      4    200
# 1           Kevin Rudd           True    196    200
# 2  Malcolm Turnbull 💉💉          False    152    200
# 3  Malcolm Turnbull 💉💉           True     48    200

# %%
Picture_df['percentage'] = [i / j * 100 for i,j in zip(Picture_df['count'], Picture_df['total'])]
Picture_df
# Out:
#                user_id  links_boolean  count  total  percentage
# 0           Kevin Rudd          False      4    200         2.0
# 1           Kevin Rudd           True    196    200        98.0
# 2  Malcolm Turnbull 💉💉          False    152    200        76.0
# 3  Malcolm Turnbull 💉💉           True     48    200        24.0

# %%
final_filter = ['user_id', 'percentage']
Picture_df_present = Picture_df[Picture_df['links_boolean'] == True]
Picture_df_present = Picture_df_present[final_filter]
Picture_df_present.head()
# Out:
#                user_id  percentage
# 1           Kevin Rudd        98.0
# 3  Malcolm Turnbull 💉💉        24.0

# %%
Picture_df_present.describe()
# Out:
#        percentage
# count    2.000000
# mean    61.000000
# std     52.325902
# min     24.000000
# 25%     42.500000
# 50%     61.000000
# 75%     79.500000
# max     98.000000

# %%
ax = Picture_df_present.plot(kind='bar', x='user_id', y= 'percentage', figsize=(15,8), width=0.4, rot=0)
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height.round(2)}%', (x + width/2, y + height*1.1), ha='center')
ax.set_ylim(0, 100)
ax.set_title('The proportions of tweets containing pictures or links')
ax.set_ylabel('Percentage')
ax.set_xlabel('User')
# Out:
# Text(0.5, 0, 'User')

# %% [markdown]
# Ref: https://www.dataquest.io/blog/matplotlib-tutorial/

# %% [markdown]
# ## Task 4

# %% [markdown]
# Use pandas to construct a histogram of the number of hashtags in tweets for each of the two users.

# %%
df['hashtags'] = df['tweet'].apply(lambda x: re.findall(r"#(\w+)", x))
df['hashtags_count'] = df['tweet'].apply(lambda x: re.findall(r"#(\w+)", x)).apply((lambda x: len(x)))
df
# Out:
#      level_0  index              user_id                 post_time  \
# 0          0      0  Malcolm Turnbull 💉💉 2021-10-15 11:54:20+00:00
# 1          1      1  Malcolm Turnbull 💉💉 2021-10-15 10:36:49+00:00
# 2          2      2  Malcolm Turnbull 💉💉 2021-10-15 08:32:01+00:00
# 3          3      3  Malcolm Turnbull 💉💉 2021-10-15 05:23:29+00:00
# 4          4      4  Malcolm Turnbull 💉💉 2021-10-14 05:02:42+00:00
# ..       ...    ...                  ...                       ...
# 395      395    195           Kevin Rudd 2021-08-16 23:51:00+00:00
# 396      396    196           Kevin Rudd 2021-08-16 15:05:08+00:00
# 397      397    197           Kevin Rudd 2021-08-16 06:54:26+00:00
# 398      398    198           Kevin Rudd 2021-08-16 05:01:02+00:00
# 399      399    199           Kevin Rudd 2021-08-15 11:58:19+00:00
#
#                                                  tweet  hour  \
# 0    RT @mjrowland68: This is quite the column by @...    11
# 1    RT @energynetworks: Join former Australian Pri...    10
# 2    RT @WarOnTheRocks: "The hyperbole around the n...     8
# 3    Australia’s ageing submarine fleet could still...     5
# 4    Andrew Forrest urges Scott Morrison to commit ...     5
# ..                                                 ...   ...
# 395  John Howard and I have been calling for this e...    23
# 396  Incompetent on vaccines. Incompetent on quaran...    15
# 397  During a national emergency, Murdoch's Sky New...     6
# 398  First, Murdoch undermines lockdowns, pressurin...     5
# 399  This is unbelievable, potentially lethal negli...    11
#
#                                     text_without_links  \
# 0    RT @mjrowland68: This is quite the column by @...
# 1    RT @energynetworks: Join former Australian Pri...
# 2    RT @WarOnTheRocks: "The hyperbole around the n...
# 3    Australia’s ageing submarine fleet could still...
# 4    Andrew Forrest urges Scott Morrison to commit ...
# ..                                                 ...
# 395  John Howard and I have been calling for this e...
# 396  Incompetent on vaccines. Incompetent on quaran...
# 397  During a national emergency, Murdoch's Sky New...
# 398  First, Murdoch undermines lockdowns, pressurin...
# 399  This is unbelievable, potentially lethal negli...
#
#                    tweet_links  links_boolean                  hashtags  \
# 0                           []          False                        []
# 1                           []          False                   [Glasg]
# 2    [https://t.co/HUQOvyL5y9]           True                        []
# 3    [https://t.co/DZPNMWIGwL]           True                        []
# 4    [https://t.co/ehIskk3GWm]           True                        []
# ..                         ...            ...                       ...
# 395  [https://t.co/r80zPrXBoK]           True                        []
# 396  [https://t.co/mKs0EtJTzk]           True                        []
# 397  [https://t.co/5BNKqLqqsc]           True  [MurdochRoyalCommission]
# 398  [https://t.co/tbWM2jU7Dw]           True  [MurdochRoyalCommission]
# 399  [https://t.co/2OrI4HcfTU]           True                        []
#
#      hashtags_count
# 0                 0
# 1                 1
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 395               0
# 396               0
# 397               1
# 398               1
# 399               0
#
# [400 rows x 11 columns]

# %%
cols = ['user_id', 'hashtags_count']
df[cols].head
# Out:
# <bound method NDFrame.head of                  user_id  hashtags_count
# 0    Malcolm Turnbull 💉💉               0
# 1    Malcolm Turnbull 💉💉               1
# 2    Malcolm Turnbull 💉💉               0
# 3    Malcolm Turnbull 💉💉               0
# 4    Malcolm Turnbull 💉💉               0
# ..                   ...             ...
# 395           Kevin Rudd               0
# 396           Kevin Rudd               0
# 397           Kevin Rudd               1
# 398           Kevin Rudd               1
# 399           Kevin Rudd               0
#
# [400 rows x 2 columns]>

# %% [markdown]
# ## Task 5
# Calculate the log odds ratio (check here for an example) for each word used in the set of tweets, and list the 20 words most strongly associated with each of the two users.

# %%
"""# **Calculating the log odds ratio**"""

import math 

new_words=[]
new_log_rat=[]



for i in list3:
  new_words.append(i)
  X=((words1[i]+1)/(total_user1+1))/((words2[i]+1)/(total_user2+1))
  x=math.log2(X)
  new_log_rat.append(x)

print(new_words)
print(new_log_rat)

df = pd.DataFrame({'new_log_rat': new_log_rat}, index=new_words)

df.head()

"""## As these are soo many words, so I will fetch only top 20 words which are common for both the users"""

df.sort_values('new_log_rat')

df_user_2=df.head(10) #Scott Morrison
df_user_1=df.tail(10) #Donald Trump

df_user_2.head() #top 10 words joined with Scott Morrison

df_user_1.head() #top 10 words joined with Donald Trump

"""## **Our final 20 words associated with both the users**"""

df = pd.concat([df_user_1,df_user_2],ignore_index=False)
df

"""# **Therefore, these words most likely to be from `user 1` and most likely from `user 2`**"""

df.plot.barh(y='new_log_rat', figsize=(20,15))

"""* **Listing the 20 words most strongly associated with each of the two users**"""

df.index

print("The 20 words most strongly associated with each of the two users are {}".format(df.index))

# %% [markdown]
# ## Task 6
# Use the vaderSentiment module to calculate the sentiment of each tweet, and then for each of the two users, calculate the average 'compound' sentiment for all their tweets.

# %%
pip install vaderSentiment

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

"""## **Sentiment of each tweet of user 1 (Donald Trump).**"""

sentence1 = df_user1['full_text'].tolist()

analyzer = SentimentIntensityAnalyzer()
for sentence in sentence1:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))

"""# Bar plot for all the average scores of `user 1`"""

Sum_neg=0
Sum_neu=0
Sum_pos=0
Sum_cmpd=0

for sentence in sentence1:
    vs_neg = analyzer.polarity_scores(sentence)['neg']
    Sum_neg=Sum_neg+vs_neg

    vs_neu = analyzer.polarity_scores(sentence)['neu']
    Sum_neu=Sum_neu+vs_neu

    vs_pos = analyzer.polarity_scores(sentence)['pos']
    Sum_pos=Sum_pos+vs_pos

    vs_cmpd = analyzer.polarity_scores(sentence)['compound']
    Sum_cmpd=Sum_cmpd+vs_cmpd






avg_neg=round(Sum_neg/200,3)
avg_neu=round(Sum_neu/200,3)
avg_pos=round(Sum_pos/200,3)
avg_cmpd=round(Sum_cmpd/200,3)

print(avg_neg)
print(avg_neu)
print(avg_pos)
print(avg_cmpd)

import matplotlib.pyplot as plt
values = [avg_neg, avg_neu, avg_pos, avg_cmpd]
x = ('negative', 'neutral', 'positive','compound')
# Create a barplot.
bar_list = plt.bar(x, values)
# Set colours.
bar_list[0].set_color('pink')
bar_list[1].set_color('sienna')
bar_list[2].set_color('cornflowerblue')
bar_list[3].set_color('blue')
# Show graphic.
plt.show()

"""### **Therefore most of the `user 1` tweets have neutral sentiment**
## **Average 'compound' sentiment for all tweets of user 1 (Donald Trump).**
"""

Sum=0

for sentence in sentence1:
    vs = analyzer.polarity_scores(sentence)['compound']
    Sum=Sum+vs
avg_cmpd=round(Sum/200,3)
print("The average 'compound' sentiment for all tweets of user 1 (Donald Trump) is {}".format(avg_cmpd)    )

# %% [markdown]
# The compound score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.

# %% [markdown]
# It is also useful for researchers who would like to set standardized thresholds for classifying sentences as either positive, neutral, or negative. Typical threshold values used most of the time are:
#
# 1. positive sentiment: compound score >= 0.05
#
# 2. neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#
# 3. negative sentiment: compound score <= -0.05

# %%
## **Sentiment of each tweet of user 2 (Scott Morrison).**
"""

sentence2 = df_user2['full_text'].tolist()

analyzer = SentimentIntensityAnalyzer()
for sentence in sentence2:
    vs = analyzer.polarity_scores(sentence)
    print("{:-<65} {}".format(sentence, str(vs)))

"""# Bar plot for all the average scores of `user 2`"""

Sum_neg=0
Sum_neu=0
Sum_pos=0
Sum_cmpd=0

for sentence in sentence2:
    vs_neg = analyzer.polarity_scores(sentence)['neg']
    Sum_neg=Sum_neg+vs_neg

    vs_neu = analyzer.polarity_scores(sentence)['neu']
    Sum_neu=Sum_neu+vs_neu

    vs_pos = analyzer.polarity_scores(sentence)['pos']
    Sum_pos=Sum_pos+vs_pos

    vs_cmpd = analyzer.polarity_scores(sentence)['compound']
    Sum_cmpd=Sum_cmpd+vs_cmpd






avg_neg=round(Sum_neg/200,3)
avg_neu=round(Sum_neu/200,3)
avg_pos=round(Sum_pos/200,3)
avg_cmpd=round(Sum_cmpd/200,3)

print(avg_neg)
print(avg_neu)
print(avg_pos)
print(avg_cmpd)

import matplotlib.pyplot as plt
values = [avg_neg, avg_neu, avg_pos, avg_cmpd]
x = ('negative', 'neutral', 'positive','compound')
# Create a barplot.
bar_list = plt.bar(x, values)
# Set colours.
bar_list[0].set_color('pink')
bar_list[1].set_color('sienna')
bar_list[2].set_color('cornflowerblue')
bar_list[3].set_color('blue')
# Show graphic.
plt.show()

"""### **Therefore most of the `user 1` tweets have neutral sentiment followed by compound ones.**
## **Average 'compound' sentiment for all tweets of user 2 (Scott Morrison).**
"""

Sum=0

for sentence in sentence2:
    vs = analyzer.polarity_scores(sentence)['compound']
    Sum=Sum+vs
avg_cmpd=round(Sum/200,3)
print("The average 'compound' sentiment for all tweets of user 2 (Scott Morrison) is {}".format(avg_cmpd)    )
